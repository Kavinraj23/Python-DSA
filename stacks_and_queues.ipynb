# %%
# stacks - LIFO
stk = []

# %%
# append to stack - O(1)
stk.append(5)

# %%
stk.append(4)
stk.append(3)

stk
# Out:
# [5, 4, 3]

# %%
# pop from stack - o(1)
x = stk.pop()

print(x, stk)
# Out:
# 3 [5, 4]

# %%
# find whats on top of stack - O(1)
print(stk[-1])
# Out:
# 4

# %%
# ask if something is in the stack - O(1)
if stk:
    print(True)
# Out:
# True

# %%
# queues - FIFO
from collections import deque # double ended queue
q = deque()
q
# Out:
# deque([])

# %%
# enqueue - add element to the right - O(1)
q.append(5)
q.append(6)
q.append(7)
q
# Out:
# deque([5, 6, 7])

# %%
# dequeue - remove elemnet form the left - O(1)
q.popleft()
q
# Out:
# deque([6, 7])

# %%
# peek from left side - O(1)
q[0]
# Out:
# 6

# %%
# peek from right side - O(1)
q[-1]
# Out:
# 7
